# %%
from random import randint
gestures = ['Rock','Paper','Scissors']
n_rounds = 0
rounds_to_win = 0
cpu_score = 0
player_score = 0
computer = gestures[randint(0,2)]
number=int(input("How many rounds do you want?"))
while n_rounds<=number:
    player = input("Rock, Paper, Scissors?")
    if player == computer:
        print("Tie!")
    elif player == "Rock":
        if computer == "Paper":
            print("You lose!", computer, "covers", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "smashes", computer)
            player_score+=1
            rounds_to_win+=1
    elif player == "Paper":
        if computer == "Scissors":
            print("You lose!", computer, "cut", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "covers", computer)
            player_score+=1
            rounds_to_win+=1
    elif player == "Scissors":
        if computer == "Rock":
            print("You lose...", computer, "smashes", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "cut", computer)
            player_score+=1
            rounds_to_win+=1
    elif rounds_to_win == number/2:
        break
    else:
        print("That's not a valid play. Check your spelling!")
    n_rounds+=1
    computer = gestures[randint(0,2)]
if cpu_score > player_score:
    print ('You lost the game')
elif cpu_score < player_score:
    print('You won the game')
elif cpu_score == player_score:
    print('It is a tie')
# Out:
# How many rounds do you want?2
# Rock, Paper, Scissors?Rock
# You lose! Paper covers Rock
# Rock, Paper, Scissors?Rock
# You lose! Paper covers Rock
# Rock, Paper, Scissors?Paper
# You lose! Scissors cut Paper
# You lost the game

# %%
from random import randint
gestures = ['Rock','Paper','Scissors','Lizard','Spock']
n_rounds = 0
rounds_to_win = 0
cpu_score = 0
player_score = 0
computer = gestures[randint(0,2)]
number=int(input("How many rounds do you want?"))
while n_rounds<=number:
    player = input("Rock, Paper, Scissors, Lizard, Spock?")
    if player == computer:
        print("Tie!")
    elif player == "Rock":
        if (computer == "Paper") | (computer=="Spock") :
            print("You lose!", computer, "covers", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "smashes", computer)
            player_score+=1
            rounds_to_win+=1
    elif player == "Paper":
        if (computer == "Scissors") | (computer == "Lizard"):
            print("You lose!", computer, "cut", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "covers", computer)
            player_score+=1
            rounds_to_win+=1
    elif player == "Scissors":
        if (computer == "Rock" | computer == "Spock"):
            print("You lose...", computer, "smashes", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "cut", computer)
            player_score+=1
            rounds_to_win+=1
    elif player == "Lizard":
        if (computer =="Scissors") | (computer == "Rock"):
            print("You lose...", computer, "smashes", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "cut", computer)
            player_score+=1
            rounds_to_win+=1
    elif player == "Spock":
        if (computer =="Paper") | (computer == "Lizard"):
            print("You lose...", computer, "smashes", player)
            cpu_score+=1
            rounds_to_win+=1
        else:
            print("You win!", player, "cut", computer)
            player_score+=1
            rounds_to_win+=1
    elif rounds_to_win == number/2:
        break
    else:
        print("That's not a valid play. Check your spelling!")
    n_rounds+=1
    computer = gestures[randint(0,2)]
if cpu_score > player_score:
    print ('You lost the game')
elif cpu_score < player_score:
    print('You won the game')
elif cpu_score == player_score:
    print('It is a tie')
# Out:
# How many rounds do you want?2
# Rock, Paper, Scissors, Lizard, Spock?Spock
# You lose... Paper smashes Spock
# Rock, Paper, Scissors, Lizard, Spock?Lizard
# You lose... Scissors smashes Lizard
# Rock, Paper, Scissors, Lizard, Spock?Rock
# Tie!
# You lost the game
